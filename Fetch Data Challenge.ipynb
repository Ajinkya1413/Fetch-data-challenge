# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
import json
import pandasql as psql
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 500
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Data Wrangling

# %%
# Initialize an empty list to store the DataFrames
# Read JSON data from the file line by line

data_list = []
dfs = []

with open('receipts.json/receipts.json') as f:
    for line in f:
        data_list.append(json.loads(line))

# %%
# Normalize and flatten the nested JSON for each object
# Concatenate all the DataFrames

for data in data_list:
    if 'rewardsReceiptItemList' in data:
        df = pd.json_normalize(data, 'rewardsReceiptItemList', 
                               [['_id','$oid'], 'bonusPointsEarned', 'bonusPointsEarnedReason', ['createDate','$date'] , 
                                ['dateScanned','$date'], 'finishedDate', 'modifyDate', 'pointsAwardedDate', 'pointsEarned',
                                'purchaseDate', 'purchasedItemCount', 'rewardsReceiptStatus', 'totalSpent', 'userId'], 
                               record_prefix='item_', errors='ignore')
        dfs.append(df)
receipts_df = pd.concat(dfs, ignore_index=True)

# %%
receipts_df.head()
# Out:
#    item_barcode                                   item_description  \
# 0          4011                                     ITEM NOT FOUND
# 1          4011                                     ITEM NOT FOUND
# 2  028400642255  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
# 3           NaN                                                NaN
# 4          4011                                     ITEM NOT FOUND
#
#   item_finalPrice item_itemPrice item_needsFetchReview item_partnerItemId  \
# 0           26.00          26.00                 False                  1
# 1               1              1                   NaN                  1
# 2           10.00          10.00                  True                  2
# 3             NaN            NaN                 False                  1
# 4           28.00          28.00                 False                  1
#
#   item_preventTargetGapPoints  item_quantityPurchased item_userFlaggedBarcode  \
# 0                        True                    5.00                    4011
# 1                         NaN                    1.00                     NaN
# 2                        True                    1.00            028400642255
# 3                        True                     NaN                    4011
# 4                        True                    4.00                    4011
#
#   item_userFlaggedNewItem item_userFlaggedPrice  item_userFlaggedQuantity  \
# 0                    True                 26.00                      5.00
# 1                     NaN                   NaN                       NaN
# 2                    True                 10.00                      1.00
# 3                    True                 26.00                      3.00
# 4                    True                 28.00                      4.00
#
#                    _id.$oid bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575               500
# 1  5ff1e1bb0a720f052300056b               150
# 2  5ff1e1bb0a720f052300056b               150
# 3  5ff1e1f10a720f052300057a                 5
# 4  5ff1e1ee0a7214ada100056f                 5
#
#                              bonusPointsEarnedReason createDate.$date  \
# 0  Receipt number 2 completed, bonus point schedu...    1609687531000
# 1  Receipt number 5 completed, bonus point schedu...    1609687483000
# 2  Receipt number 5 completed, bonus point schedu...    1609687483000
# 3                         All-receipts receipt bonus    1609687537000
# 4                         All-receipts receipt bonus    1609687534000
#
#   dateScanned.$date              finishedDate                modifyDate  \
# 0     1609687531000  {'$date': 1609687531000}  {'$date': 1609687536000}
# 1     1609687483000  {'$date': 1609687483000}  {'$date': 1609687488000}
# 2     1609687483000  {'$date': 1609687483000}  {'$date': 1609687488000}
# 3     1609687537000                       NaN  {'$date': 1609687542000}
# 4     1609687534000  {'$date': 1609687534000}  {'$date': 1609687539000}
#
#           pointsAwardedDate pointsEarned              purchaseDate  \
# 0  {'$date': 1609687531000}        500.0  {'$date': 1609632000000}
# 1  {'$date': 1609687483000}        150.0  {'$date': 1609601083000}
# 2  {'$date': 1609687483000}        150.0  {'$date': 1609601083000}
# 3                       NaN            5  {'$date': 1609632000000}
# 4  {'$date': 1609687534000}          5.0  {'$date': 1609632000000}
#
#   purchasedItemCount rewardsReceiptStatus totalSpent  \
# 0                  5             FINISHED      26.00
# 1                  2             FINISHED      11.00
# 2                  2             FINISHED      11.00
# 3                  1             REJECTED      10.00
# 4                  4             FINISHED      28.00
#
#                      userId item_needsFetchReviewReason  \
# 0  5ff1e1eacfcf6c399c274ae6                         NaN
# 1  5ff1e194b6a9d73a3a9f1052                         NaN
# 2  5ff1e194b6a9d73a3a9f1052                USER_FLAGGED
# 3  5ff1e1f1cfcf6c399c274b0b                         NaN
# 4  5ff1e1eacfcf6c399c274ae6                         NaN
#
#            item_pointsNotAwardedReason        item_pointsPayerId  \
# 0                                  NaN                       NaN
# 1                                  NaN                       NaN
# 2  Action not allowed for user and CPG  5332f5fbe4b03c9a25efd0ba
# 3                                  NaN                       NaN
# 4                                  NaN                       NaN
#
#                         item_rewardsGroup item_rewardsProductPartnerId  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2  DORITOS SPICY SWEET CHILI SINGLE SERVE     5332f5fbe4b03c9a25efd0ba
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
#
#                          item_userFlaggedDescription  \
# 0                                                NaN
# 1                                                NaN
# 2  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...
# 3                                                NaN
# 4                                                NaN
#
#   item_originalMetaBriteBarcode item_originalMetaBriteDescription  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#   item_brandCode item_competitorRewardsGroup item_discountedItemPrice  \
# 0            NaN                         NaN                      NaN
# 1            NaN                         NaN                      NaN
# 2            NaN                         NaN                      NaN
# 3            NaN                         NaN                      NaN
# 4            NaN                         NaN                      NaN
#
#   item_originalReceiptItemText item_itemNumber  \
# 0                          NaN             NaN
# 1                          NaN             NaN
# 2                          NaN             NaN
# 3                          NaN             NaN
# 4                          NaN             NaN
#
#    item_originalMetaBriteQuantityPurchased item_pointsEarned item_targetPrice  \
# 0                                      NaN               NaN              NaN
# 1                                      NaN               NaN              NaN
# 2                                      NaN               NaN              NaN
# 3                                      NaN               NaN              NaN
# 4                                      NaN               NaN              NaN
#
#   item_competitiveProduct item_originalFinalPrice  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#   item_originalMetaBriteItemPrice item_deleted item_priceAfterCoupon  \
# 0                             NaN          NaN                   NaN
# 1                             NaN          NaN                   NaN
# 2                             NaN          NaN                   NaN
# 3                             NaN          NaN                   NaN
# 4                             NaN          NaN                   NaN
#
#   item_metabriteCampaignId
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
#select the important columns

receipts_df_final = receipts_df[['item_barcode', 'item_finalPrice', 'item_itemPrice', '_id.$oid', 'createDate.$date',  
                           'purchasedItemCount', 'totalSpent', 'userId', 'item_itemNumber', 'item_brandCode',
                                 'dateScanned.$date', 'rewardsReceiptStatus']]

# %%
#rename columns

receipts_df_final.rename(columns={'_id.$oid': 'id'}, inplace=True)
receipts_df_final.rename(columns={'createDate.$date': 'createTimestamp'}, inplace=True)
receipts_df_final.rename(columns={'dateScanned.$date': 'dateScannedTimestamp'}, inplace=True)

# %%
receipts_df_final.head()
# Out:
#    item_barcode item_finalPrice item_itemPrice                        id  \
# 0          4011           26.00          26.00  5ff1e1eb0a720f0523000575
# 1          4011               1              1  5ff1e1bb0a720f052300056b
# 2  028400642255           10.00          10.00  5ff1e1bb0a720f052300056b
# 3           NaN             NaN            NaN  5ff1e1f10a720f052300057a
# 4          4011           28.00          28.00  5ff1e1ee0a7214ada100056f
#
#   createTimestamp purchasedItemCount totalSpent                    userId  \
# 0   1609687531000                  5      26.00  5ff1e1eacfcf6c399c274ae6
# 1   1609687483000                  2      11.00  5ff1e194b6a9d73a3a9f1052
# 2   1609687483000                  2      11.00  5ff1e194b6a9d73a3a9f1052
# 3   1609687537000                  1      10.00  5ff1e1f1cfcf6c399c274b0b
# 4   1609687534000                  4      28.00  5ff1e1eacfcf6c399c274ae6
#
#   item_itemNumber item_brandCode dateScannedTimestamp rewardsReceiptStatus
# 0             NaN            NaN        1609687531000             FINISHED
# 1             NaN            NaN        1609687483000             FINISHED
# 2             NaN            NaN        1609687483000             FINISHED
# 3             NaN            NaN        1609687537000             REJECTED
# 4             NaN            NaN        1609687534000             FINISHED

# %%
# Initialize an empty list to store the DataFrames

dfs = []
data_list = []

with open('brands.json/brands.json') as f:
    for line in f:
        data_list.append(json.loads(line))

# %%
# Normalize the JSON data
# Concatenate all the DataFrames

for data in data_list:
    df = pd.json_normalize(data)
    dfs.append(df)
    
brands_df = pd.concat(dfs, ignore_index=True)

# %%
#Rename columns

brands_df.rename(columns={'_id.$oid': 'id'}, inplace=True)
brands_df.rename(columns={'cpg.$id.$oid': 'cpgId'}, inplace=True)
brands_df.rename(columns={'cpg.$ref': 'cpgRef'}, inplace=True)

# %%
brands_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   barcode       1167 non-null   object
#  1   category      1012 non-null   object
#  2   categoryCode  517 non-null    object
#  3   name          1167 non-null   object
#  4   topBrand      555 non-null    object
#  5   id            1167 non-null   object
#  6   cpgId         1167 non-null   object
#  7   cpgRef        1167 non-null   object
#  8   brandCode     933 non-null    object
# dtypes: object(9)
# memory usage: 82.2+ KB

# %%
brands_df.head()
# Out:
#         barcode        category      categoryCode                       name  \
# 0  511111019862          Baking            BAKING  test brand @1612366101024
# 1  511111519928       Beverages         BEVERAGES                  Starbucks
# 2  511111819905          Baking            BAKING  test brand @1612366146176
# 3  511111519874          Baking            BAKING  test brand @1612366146051
# 4  511111319917  Candy & Sweets  CANDY_AND_SWEETS  test brand @1612366146827
#
#   topBrand                        id                     cpgId cpgRef  \
# 0    False  601ac115be37ce2ead437551  601ac114be37ce2ead437550   Cogs
# 1    False  601c5460be37ce2ead43755f  5332f5fbe4b03c9a25efd0ba   Cogs
# 2    False  601ac142be37ce2ead43755d  601ac142be37ce2ead437559   Cogs
# 3    False  601ac142be37ce2ead43755a  601ac142be37ce2ead437559   Cogs
# 4    False  601ac142be37ce2ead43755e  5332fa12e4b03c9a25efd1e7   Cogs
#
#                        brandCode
# 0                            NaN
# 1                      STARBUCKS
# 2  TEST BRANDCODE @1612366146176
# 3  TEST BRANDCODE @1612366146051
# 4  TEST BRANDCODE @1612366146827

# %%
# Initialize an empty list to store the data
# Read JSON data from the file line by line

data_list = []
dfs = []

with open('users.json/users.json') as f:
    for line in f:
        data_list.append(json.loads(line))

# %%
# Normalize the JSON data
# Concatenate all the DataFrames

for data in data_list:
    df = pd.json_normalize(data)
    dfs.append(df)
    
users_df = pd.concat(dfs, ignore_index=True)

# %%
# Rename the columns

users_df.rename(columns={'_id.$oid': 'id'}, inplace=True)
users_df.rename(columns={'createdDate.$date': 'createdTimestamp'}, inplace=True)
users_df.rename(columns={'lastLogin.$date': 'lastLoginTimestamp'}, inplace=True)

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   active              495 non-null    bool
#  1   role                495 non-null    object
#  2   signUpSource        447 non-null    object
#  3   state               439 non-null    object
#  4   id                  495 non-null    object
#  5   createdTimestamp    495 non-null    int64
#  6   lastLoginTimestamp  433 non-null    float64
# dtypes: bool(1), float64(1), int64(1), object(4)
# memory usage: 23.8+ KB

# %%
#A function to convert the timestamp into datetime

def convert_timestamp(df, convert_col_name, new_col_name):
    df[new_col_name] = pd.to_datetime(df[convert_col_name], unit='ms')
    return df

# %%
#Converting the the timestamps for receipts

receipts_df_final = convert_timestamp(receipts_df_final, 'createTimestamp', 'createDate')
receipts_df_final = convert_timestamp(receipts_df_final, 'dateScannedTimestamp', 'dateScannedDate')
receipts_df_final.head()
# Out:
#    item_barcode item_finalPrice item_itemPrice                        id  \
# 0          4011           26.00          26.00  5ff1e1eb0a720f0523000575
# 1          4011               1              1  5ff1e1bb0a720f052300056b
# 2  028400642255           10.00          10.00  5ff1e1bb0a720f052300056b
# 3           NaN             NaN            NaN  5ff1e1f10a720f052300057a
# 4          4011           28.00          28.00  5ff1e1ee0a7214ada100056f
#
#   createTimestamp purchasedItemCount totalSpent                    userId  \
# 0   1609687531000                  5      26.00  5ff1e1eacfcf6c399c274ae6
# 1   1609687483000                  2      11.00  5ff1e194b6a9d73a3a9f1052
# 2   1609687483000                  2      11.00  5ff1e194b6a9d73a3a9f1052
# 3   1609687537000                  1      10.00  5ff1e1f1cfcf6c399c274b0b
# 4   1609687534000                  4      28.00  5ff1e1eacfcf6c399c274ae6
#
#   item_itemNumber item_brandCode dateScannedTimestamp rewardsReceiptStatus  \
# 0             NaN            NaN        1609687531000             FINISHED
# 1             NaN            NaN        1609687483000             FINISHED
# 2             NaN            NaN        1609687483000             FINISHED
# 3             NaN            NaN        1609687537000             REJECTED
# 4             NaN            NaN        1609687534000             FINISHED
#
#            createDate     dateScannedDate
# 0 2021-01-03 15:25:31 2021-01-03 15:25:31
# 1 2021-01-03 15:24:43 2021-01-03 15:24:43
# 2 2021-01-03 15:24:43 2021-01-03 15:24:43
# 3 2021-01-03 15:25:37 2021-01-03 15:25:37
# 4 2021-01-03 15:25:34 2021-01-03 15:25:34

# %%
#Converting the the timestamps for users

users_df = convert_timestamp(users_df, 'createdTimestamp', 'createdDate')
users_df = convert_timestamp(users_df, 'lastLoginTimestamp', 'lastLoginDate')
users_df.head()
# Out:
#    active      role signUpSource state                        id  \
# 0    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 1    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 2    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
# 3    True  consumer        Email    WI  5ff1e1eacfcf6c399c274ae6
# 4    True  consumer        Email    WI  5ff1e194b6a9d73a3a9f1052
#
#    createdTimestamp   lastLoginTimestamp             createdDate  \
# 0     1609687444800 1,609,687,537,858.00 2021-01-03 15:24:04.800
# 1     1609687444800 1,609,687,537,858.00 2021-01-03 15:24:04.800
# 2     1609687444800 1,609,687,537,858.00 2021-01-03 15:24:04.800
# 3     1609687530554 1,609,687,530,597.00 2021-01-03 15:25:30.554
# 4     1609687444800 1,609,687,537,858.00 2021-01-03 15:24:04.800
#
#                   lastLoginDate
# 0 2021-01-03 15:25:37.857999872
# 1 2021-01-03 15:25:37.857999872
# 2 2021-01-03 15:25:37.857999872
# 3 2021-01-03 15:25:30.596999936
# 4 2021-01-03 15:25:37.857999872

# %% [markdown]
# ### Answers
# #### Q1 What are the top 5 brands by receipts scanned for most recent month?
# #### Q2 How does the ranking of the top 5 brands by receipts scanned for the recent month compare to the ranking for the previous month?

# %%
query = """
WITH prev_mon_cte AS
(
         SELECT   item_brandcode,
                  Count(DISTINCT(id)) AS receipt_count_prev_mon
         FROM     receipts_df_final
         WHERE    datescanneddate BETWEEN '2021-01-01' AND '2021-01-31'
         AND      item_brandcode != 'None'
         GROUP BY item_brandcode
         ORDER BY receipt_count_prev_mon DESC)
SELECT    rf.item_brandcode,
          Count(DISTINCT(rf.id)) AS receipt_count_latest_mon,
          pm.receipt_count_prev_mon
FROM      receipts_df_final rf
LEFT JOIN prev_mon_cte pm
ON        pm.item_brandcode = rf.item_brandcode
WHERE     rf.datescanneddate BETWEEN '2021-02-01' AND '2021-02-28'
AND       rf.item_brandcode != 'None'
GROUP BY  rf.item_brandcode
ORDER BY  receipt_count_latest_mon DESC limit 5;
"""

result = psql.sqldf(query, locals())
result
# Out:
#   item_brandCode  receipt_count_latest_mon  receipt_count_prev_mon
# 0          BRAND                         3                   19.00
# 1        MISSION                         2                   16.00
# 2           VIVA                         1                     NaN

# %% [markdown]
# * In the above table we can see the three brands with their latest month(February 2021) receipt count and their previous month(January 2021) receipt count.
# * There are only 3 when 5 were asked, as the latest month has less data.

# %% [markdown]
# #### Q3 When considering average spend from receipts with 'rewardsReceiptStatus’ of ‘Accepted’ or ‘Rejected’, which is greater?

# %%
query = """
SELECT Avg(CASE
             WHEN rewardsreceiptstatus = 'FINISHED' THEN totalspent
             ELSE NULL
           END) AS Finished_Amt,
       Avg(CASE
             WHEN rewardsreceiptstatus = 'REJECTED' THEN totalspent
             ELSE NULL
           END) AS Rejected_Amt
FROM   receipts_df_final;
"""

result = psql.sqldf(query, locals())
result
# Out:
#    Finished_Amt  Rejected_Amt
# 0      1,244.79         19.90

# %% [markdown]
# * Assuming the question ment 'Finished' and 'Rejected', above are the average amounts for both of them.
# * Here Finished amount is far greater than Rejected amount based on total spent.

# %% [markdown]
# #### Q4 When considering total number of items purchased from receipts with 'rewardsReceiptStatus’ of ‘Accepted’ or ‘Rejected’, which is greater?

# %%
query = """
SELECT Sum(CASE
             WHEN rewardsreceiptstatus = 'FINISHED' THEN purchaseditemcount
             ELSE 0
           END) AS Finished_item_count,
       Sum(CASE
             WHEN rewardsreceiptstatus = 'REJECTED' THEN purchaseditemcount
             ELSE 0
           END) AS Rejected_item_count
FROM   receipts_df_final; 
"""

result = psql.sqldf(query, locals())
result
# Out:
#    Finished_item_count  Rejected_item_count
# 0              1364998                  740

# %% [markdown]
# * Again, assuming the question ment 'Finished' and 'Rejected', above are the item counts for both of them.
# * Here Finished item count is far greater than Rejected count based on purchased Item Count.

# %% [markdown]
# #### Q5 Which brand has the most spend among users who were created within the past 6 months?

# %%
query = """
SELECT rf.item_brandcode,
       Sum(rf.totalspent) total_Brand_Spent
FROM   receipts_df_final rf
WHERE  rf.userid IN (SELECT id
                     FROM   users_df
                     WHERE  createddate BETWEEN '2020-09-01' AND '2021-02-31'
                            AND role = 'consumer')
       AND rf.item_brandcode != 'None'
GROUP  BY 1
ORDER  BY 2 DESC
LIMIT  1; 
"""

result = psql.sqldf(query, locals())
result
# Out:
#    item_brandCode  total_Brand_Spent
# 0  BEN AND JERRYS         197,337.68

# %% [markdown]
# * 'BEN AND JERRYS' has the most spend among users who were created within the last 6 months from the max date

# %% [markdown]
# #### Figuring out the Primark Key for Receipts and users dataset after flattening(unnesting)

# %%
# Tried all selected columns as composit primary key for receipt dataset(after flattening).
# But it is not working as there are duplicate rows. We might need to create a new column as a primary key

query = """
SELECT id,
       item_barcode,
       item_finalprice,
       item_itemprice,
       createtimestamp,
       purchaseditemcount,
       totalspent,
       userid,
       item_itemnumber,
       item_brandcode,
       datescannedtimestamp,
       createdate,
       Count(*) as duplicate_count
FROM   receipts_df_final
GROUP  BY id,
          item_barcode,
          item_finalprice,
          item_itemprice,
          createtimestamp,
          purchaseditemcount,
          totalspent,
          userid,
          item_itemnumber,
          item_brandcode,
          datescannedtimestamp,
          createdate
HAVING Count(*) > 1; 
"""

result = psql.sqldf(query, locals())
result
# Out:
#                            id   item_barcode item_finalPrice item_itemPrice  \
# 0    5f9c74f70a7214ad07000037           None            None           None
# 1    5f9c74f90a7214ad07000038   034100573065            1.00           1.00
# 2    5fa5ad370a720f05ef000089   034100573065           29.00          29.00
# 3    5fa5b0ca0a720f05ef0000bf   034100573065            1.00           1.00
# 4    5fa8d5730a7214adc30001c3           None            None           None
# 5    5fa8d5790a7214adc30001c4   034100573065            1.00           1.00
# 542  600eda0c0a7214ada200001e           None            2.34           2.34
# 543  600eda0c0a7214ada200001e           None            2.49           2.49
# 544  600eda0c0a7214ada200001e           None            2.62           2.62
# 545  600eda0c0a7214ada200001e           None            2.99           2.99
# 546  600eda0c0a7214ada200001e           None           23.99          23.99
# 547  600eda0c0a7214ada200001e           None            3.37           3.37
# 548  600eda0c0a7214ada200001e           None            3.38           3.38
# 549  600eda0c0a7214ada200001e           None            3.49           3.49
# 550  600eda0c0a7214ada200001e           None            3.51           3.51
# 551  600eda0c0a7214ada200001e           None            3.79           3.79
# 552  600eda0c0a7214ada200001e           None            3.99           3.99
# 553  600eda0c0a7214ada200001e           None            4.97           4.97
# 554  600eda0c0a7214ada200001e           None            4.98           4.98
# 555  600eda0c0a7214ada200001e           None            4.99           4.99
# 556  600eda0c0a7214ada200001e           None            5.19           5.19
# 557  600eda0c0a7214ada200001e           None            5.59           5.59
# 558  600eda0c0a7214ada200001e           None            5.99           5.99
# 559  600eda0c0a7214ada200001e           None            6.74           6.74
# 560  600eda0c0a7214ada200001e           None            8.38           8.38
# 561  600eda0c0a7214ada200001e           None            8.98           8.98
# 562  600eda0c0a7214ada200001e           None            9.17           9.17
# 563  600eda0c0a7214ada200001e           None            9.99           9.99
# 564  600edb570a720f053500001d           None            0.69           0.69
# 565  600edb570a720f053500001d           None            0.75           0.75
# 566  600edb570a720f053500001d           None            0.89           0.89
# 567  600edb570a720f053500001d           None            1.49           1.49
# 568  600edb570a720f053500001d           None            1.79           1.79
# 569  600edb570a720f053500001d           None            1.99           1.99
# 570  600edb570a720f053500001d           None           14.99          14.99
# 571  600edb570a720f053500001d           None            2.29           2.29
# 572  600edb570a720f053500001d           None            2.34           2.34
# 573  600edb570a720f053500001d           None            2.74           2.74
# 574  600edb570a720f053500001d           None            2.79           2.79
# 575  600edb570a720f053500001d           None            3.37           3.37
# 576  600edb570a720f053500001d           None            3.49           3.49
# 577  600edb570a720f053500001d           None            3.98           3.98
# 578  600edb570a720f053500001d           None            3.99           3.99
# 579  600edb570a720f053500001d           None            3.99           3.99
# 580  600edb570a720f053500001d           None            4.19           4.19
# 581  600edb570a720f053500001d           None            4.49           4.49
# 582  600edb570a720f053500001d           None            4.99           4.99
# 583  600edb570a720f053500001d           None            5.19           5.19
# 584  600edb570a720f053500001d           None            5.49           5.49
# 585  600edb570a720f053500001d           None            6.49           6.49
# 586  600edb570a720f053500001d   026800001924            0.89           0.89
# 587  600edb570a720f053500001d   026800001924            1.39           1.39
# 588  600edb570a720f053500001d   311111511867            5.59           5.59
# 589  600f012c0a720f0535000025   041129412152               5              5
# 590  600f01310a7214ada2000027   029000019201            9.99           9.99
# 591  600f01340a7214ada2000029   021000068883            9.99           9.99
# 592  600f0cc70a720f053500002c           None            0.50           0.50
# 593  600f0cc70a720f053500002c           None            0.56           0.56
# 594  600f0cc70a720f053500002c           None            0.69           0.69
# 595  600f0cc70a720f053500002c           None            1.00           1.00
# 596  600f0cc70a720f053500002c           None            1.80           1.80
# 597  600f0cc70a720f053500002c           None            1.99           1.99
# 866  2021-01-26 06:09:30.000000                5
# 867  2021-01-26 06:09:32.000000                5
# 868  2021-01-26 06:09:33.000000                5
# 869  2021-01-27 01:12:56.000000               10
# 870  2021-01-27 01:13:00.000000                2
# 871  2021-01-28 16:28:17.000000                4
# 872  2021-01-28 16:28:29.000000                4
# 873  2021-01-28 16:28:40.000000                4
# 874  2021-01-28 16:28:51.000000                4
# 875  2021-01-28 16:29:02.000000                4
# 876  2021-01-28 16:29:03.000000                4
# 877  2021-01-28 16:29:15.000000                4
# 878  2021-01-28 16:29:22.000000                4
# 879  2021-01-28 16:29:26.000000                4
# 880  2021-01-28 16:29:32.000000                4
# 881  2021-01-28 16:29:37.000000                4
# 882  2021-01-28 16:29:41.000000                4
# 883  2021-01-28 16:29:56.000000                4
# 884  2021-01-28 16:29:57.000000                4
# 885  2021-01-28 21:24:25.000000                2
# 886  2021-01-28 22:55:56.000000                4
# 887  2021-01-28 22:55:59.000000                4
# 888  2021-01-28 22:56:04.000000                4
# 889  2021-01-28 22:56:12.000000                4
# 890  2021-01-28 22:56:15.000000                4
# 891  2021-01-28 22:56:21.000000                4
# 892  2021-01-28 22:56:22.000000                4
# 893  2021-01-29 17:14:25.000000                5
# 894  2021-01-29 17:42:11.000000                5
# 895  2021-01-29 18:56:20.000000                2
# 896  2021-01-29 20:27:41.000000                5
# 897  2021-01-29 20:41:06.000000                4
# 898  2021-01-29 21:18:24.000000                5
# 899  2021-02-01 16:48:13.000000                2
# 900  2021-02-02 00:27:49.000000               10
# 901  2021-02-02 00:28:02.000000                2
# 902  2021-02-03 14:12:40.000000                5
# 903  2021-02-10 15:56:59.000000                5
# 904  2021-02-10 15:56:59.000000                5
# 905  2021-02-10 15:57:41.000000                5
# 906  2021-02-10 18:44:35.000000                5

# %%
# id supposed to be the primary key of this data but there are duplicates for it.
# Tried with various composit primary keys as well, dosen't seem to work. We need to throughly look into data.

query = """
SELECT id,
       createdTimestamp,
       Count(*) as duplicate_count
FROM   users_df
GROUP  BY id,
          createdTimestamp
HAVING Count(*) > 1; 
"""

result = psql.sqldf(query, locals())
result
# Out:
#                           id  createdTimestamp  duplicate_count
# 0   54943462e4b07e684157a532     1418998882381               20
# 1   59c124bae4b0299e55b0f330     1505830074302               18
# 2   5a43c08fe4b014fd6b6a0612     1514389647059                8
# 3   5fa41775898c7a11a6bcef3e     1604589429396               18
# 4   5fb0a078be5fc9775c1f3945     1605410936818                2
# 5   5fbc35711d967d1222cbfefc     1606169969509                3
# 6   5fc961c3b8cfca11a077dd33     1607033283936               20
# 7   5ff1e194b6a9d73a3a9f1052     1609687444800               11
# 8   5ff1e1eacfcf6c399c274ae6     1609687530554                4
# 9   5ff36a3862fde912123a4460     1609787960352                5
# 10  5ff36be7135e7011bcb856d3     1609788391239                3
# 11  5ff36d0362fde912123a5535     1609788675973                3
# 12  5ff370c562fde912123a5e0e     1609789637776                5
# 13  5ff47392c3d63511e2a47881     1609855890233                5
# 14  5ff4ce33c3d63511e2a484b6     1609879091229                7
